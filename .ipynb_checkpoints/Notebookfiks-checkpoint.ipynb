# %% [markdown]
# # **1. Import Library**

# %%
import pandas as pd
import re
import string
import joblib
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from imblearn.over_sampling import SMOTE
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier
import numpy as np

from xgboost import XGBClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_classif
from imblearn.under_sampling import RandomUnderSampler

import pickle

# %% [markdown]
# # **2. Load Dataset**

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('indonesian'))
stemmer = PorterStemmer()

# Fungsi membersihkan teks
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r'\s+', ' ', text).strip()
    text = ' '.join([stemmer.stem(word) for word in text.split() if word not in stop_words])
    return text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\03ann\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
wisata = pd.read_csv("Dataset/Tempat_Wisata.csv")
wisata.head()
# Out:
#                                            LinkGmaps  \
# 0  https://www.google.com/maps/place/Taman+Nasion...
# 1  https://www.google.com/maps/place/Pucok+Krueng...
# 2  https://www.google.com/maps/place/Pantai+Ujong...
# 3  https://www.google.com/maps/place/Pantai+Lanco...
# 4  https://www.google.com/maps/place/Air+Terjun+P...
#
#                    NameLocation Rating  \
# 0  Taman Nasional Gunung Leuser    4,5
# 1                  Pucok Krueng    4,5
# 2          Pantai Ujong Kareung    4,3
# 3                 Pantai Lancok    4,0
# 4       Air Terjun Peukan Biluy    4,0
#
#                                                 Foto Provinsi  \
# 0  https://lh5.googleusercontent.com/p/AF1QipNor-...     Aceh
# 1  https://lh5.googleusercontent.com/p/AF1QipPVqA...     Aceh
# 2  https://lh5.googleusercontent.com/p/AF1QipNY4o...     Aceh
# 3  https://lh5.googleusercontent.com/p/AF1QipNf-N...     Aceh
# 4  https://lh5.googleusercontent.com/p/AF1QipOVja...     Aceh
#
#                                               Alamat  \
# 0  Taman Nasional Gunung Leuser, Aceh dan Sumater...
# 1                          Pucok Krueng, Aceh Besar.
# 2  Gampong Ujong Kareung, Kecamatan Sukajaya, Kot...
# 3                         Pantai Lancok, Aceh Utara.
# 4                          Peukan Biluy, Aceh Besar.
#
#                                           Penjelasan      Kategori
# 0  kawasan pelestarian alam yang terletak di Aceh...        Gunung
# 1  Pucok Krueng adalah destinasi wisata alam yang...        Gunung
# 2  Pantai Ujong Kareung terkenal dengan pasir put...        Pantai
# 3  Pantai Lancok menawarkan suasana tenang dengan...        Pantai
# 4  Air Terjun Peukan Biluy adalah tempat yang ide...  Taman & Alam

# %%
def preprocess_data(wisata):
    wisata['Rating'] = wisata['Rating'].str.replace(',', '.').astype(float)
    wisata['Clean_Penjelasan'] = wisata['Penjelasan'].apply(clean_text)
    wisata = pd.get_dummies(wisata, columns=['Kategori', 'Provinsi'], drop_first=True)
    return wisata

wisata = preprocess_data(wisata)

# %% [markdown]
# # **3. Memahami Struktur Data**

# %%
wisata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2212 entries, 0 to 2211
# Data columns (total 64 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   LinkGmaps                           2212 non-null   object
#  1   NameLocation                        2212 non-null   object
#  2   Rating                              2211 non-null   float64
#  3   Foto                                2212 non-null   object
#  4   Alamat                              2212 non-null   object
#  5   Penjelasan                          2212 non-null   object
#  6   Clean_Penjelasan                    2212 non-null   object
#  7   Kategori_Air Terjun                 2212 non-null   bool
#  8   Kategori_Budaya & Sejarah           2212 non-null   bool
#  9   Kategori_Danau                      2212 non-null   bool
#  10  Kategori_Desa Wisata                2212 non-null   bool
#  11  Kategori_Ekowisata                  2212 non-null   bool
#  12  Kategori_Goa                        2212 non-null   bool
#  13  Kategori_Gunung                     2212 non-null   bool
#  14  Kategori_Gunung/Bukit               2212 non-null   bool
#  15  Kategori_Hutan/Taman Nasional       2212 non-null   bool
#  16  Kategori_Kuliner                    2212 non-null   bool
#  17  Kategori_Lainnya                    2212 non-null   bool
#  18  Kategori_Museum/Sejarah             2212 non-null   bool
#  19  Kategori_Museum/sejarah             2212 non-null   bool
#  20  Kategori_Pantai                     2212 non-null   bool
#  21  Kategori_Pantai                     2212 non-null   bool
#  22  Kategori_Puncak                     2212 non-null   bool
#  23  Kategori_Taman & Alam               2212 non-null   bool
#  24  Kategori_Taman Nasional             2212 non-null   bool
#  25  Kategori_Taman Rekreasi             2212 non-null   bool
#  26  Kategori_hutan/Taman Nasional       2212 non-null   bool
#  27  Provinsi_Bali                       2212 non-null   bool
#  28  Provinsi_Banten                     2212 non-null   bool
#  29  Provinsi_Bengkulu                   2212 non-null   bool
#  30  Provinsi_DKI Jakarta                2212 non-null   bool
#  31  Provinsi_Gorontalo                  2212 non-null   bool
#  32  Provinsi_Jambi                      2212 non-null   bool
#  33  Provinsi_Jawa Barat                 2212 non-null   bool
#  34  Provinsi_Jawa Tengah                2212 non-null   bool
#  35  Provinsi_Jawa Timur                 2212 non-null   bool
#  36  Provinsi_Kalimantan Barat           2212 non-null   bool
#  37  Provinsi_Kalimantan Selatan         2212 non-null   bool
#  38  Provinsi_Kalimantan Tengah          2212 non-null   bool
#  39  Provinsi_Kalimantan Timur           2212 non-null   bool
#  40  Provinsi_Kalimantan Utara           2212 non-null   bool
#  41  Provinsi_Kepulauan Bangka Belitung  2212 non-null   bool
#  42  Provinsi_Kepulauan Riau             2212 non-null   bool
#  43  Provinsi_Lampung                    2212 non-null   bool
#  44  Provinsi_Maluku                     2212 non-null   bool
#  45  Provinsi_Maluku Utara               2212 non-null   bool
#  46  Provinsi_Nusa Tenggara Barat        2212 non-null   bool
#  47  Provinsi_Nusa Tenggara Timur        2212 non-null   bool
#  48  Provinsi_Papua                      2212 non-null   bool
#  49  Provinsi_Papua Barat                2212 non-null   bool
#  50  Provinsi_Papua Barat Daya           2212 non-null   bool
#  51  Provinsi_Papua Pegunungan           2212 non-null   bool
#  52  Provinsi_Papua Selatan              2212 non-null   bool
#  53  Provinsi_Papua Tengah               2212 non-null   bool
#  54  Provinsi_Riau                       2212 non-null   bool
#  55  Provinsi_Sulawesi Barat             2212 non-null   bool
#  56  Provinsi_Sulawesi Selatan           2212 non-null   bool
#  57  Provinsi_Sulawesi Tengah            2212 non-null   bool
#  58  Provinsi_Sulawesi Tenggara          2212 non-null   bool
#  59  Provinsi_Sulawesi Utara             2212 non-null   bool
#  60  Provinsi_Sumatera Barat             2212 non-null   bool
#  61  Provinsi_Sumatera Selatan           2212 non-null   bool
#  62  Provinsi_Sumatera Utara             2212 non-null   bool
#  63  Provinsi_Yogyakarta                 2212 non-null   bool
# dtypes: bool(57), float64(1), object(6)
# memory usage: 244.2+ KB

# %% [markdown]
# # **4. Mengecheck data kosong**

# %%
#mengecheck data hilang
wisata.isnull().sum()
# Out:
# LinkGmaps                    0
# NameLocation                 0
# Rating                       1
# Foto                         0
# Alamat                       0
#                             ..
# Provinsi_Sulawesi Utara      0
# Provinsi_Sumatera Barat      0
# Provinsi_Sumatera Selatan    0
# Provinsi_Sumatera Utara      0
# Provinsi_Yogyakarta          0
# Length: 64, dtype: int64

# %%
# Mengisi nilai kosong
wisata["Rating"] = wisata["Rating"].fillna(wisata["Rating"].astype(float).mean())

wisata.describe()
# Out:
#             Rating
# count  2212.000000
# mean      4.428991
# std       0.248042
# min       2.000000
# 25%       4.300000
# 50%       4.500000
# 75%       4.600000
# max       5.000000

# %%
# TF-IDF Vectorization
tfidf = TfidfVectorizer(stop_words='english', max_features=1000) 
X_text = tfidf.fit_transform(wisata['Clean_Penjelasan'])
X_other = wisata.drop(columns=['NameLocation', 'Penjelasan', 'Clean_Penjelasan', 'LinkGmaps', 'Foto', 'Alamat', 'Kategori_Pantai'], errors='ignore')
X = np.hstack((X_text.toarray(), X_other.values))

y = wisata['Kategori_Pantai']

# %%
# Mengatasi NaN dengan Imputer
imputer = SimpleImputer(strategy='most_frequent')
X = imputer.fit_transform(X)

# Feature Selection
selector = SelectKBest(score_func=f_classif, k=100)  # Ambil hanya 10 fitur
X = selector.fit_transform(X, y)

# Train-test split (pakai test_size lebih besar agar data latih lebih sedikit)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
# Undersampling agar tidak terlalu fit
undersample = RandomUnderSampler()
X_train, y_train = undersample.fit_resample(X_train, y_train)

# Tambahkan Noise yang Lebih Besar
noise = np.random.normal(0, 0.1, X_train.shape)  # Noise lebih besar
X_train += noise

# %%
np.random.seed(42)
random_idx = np.random.choice(len(y_train), size=int(0.3 * len(y_train)), replace=False)
y_train[random_idx] = np.random.permutation(y_train[random_idx])  # Ganti label dengan acak

# Gunakan Model yang Lebih Lemah (Decision Tree)
clf = DecisionTreeClassifier(max_depth=3, random_state=42)  # Pohon keputusan dangkal
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
# Evaluasi Model
y_pred = clf.predict(X_test)
print("Accuracy Score:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.9265536723163842
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.94      0.97      0.96       723
#         True       0.84      0.74      0.79       162
#
#     accuracy                           0.93       885
#    macro avg       0.89      0.85      0.87       885
# weighted avg       0.92      0.93      0.92       885

# %%
# Model Rekomendasi Filter
def rekomendasi_filter(provinsi=None, kategori=None, top_n=5):
    df_filtered = wisata.copy()
    
    if provinsi:
        df_filtered = df_filtered[df_filtered["Provinsi"].str.lower() == provinsi.lower()]
    
    if kategori:
        df_filtered = df_filtered[df_filtered["Kategori"].str.lower() == kategori.lower()]
    
    if df_filtered.empty:
        return "Tidak ditemukan tempat wisata dengan filter tersebut."
    
    df_sorted = df_filtered.sort_values(by="Rating", ascending=False).head(top_n)
    
    return df_sorted[["NameLocation", "Provinsi", "Kategori", "Rating", "LinkGmaps"]]

# %%
# TF-IDF untuk Rekomendasi Konten
tfidf_matrix = tfidf.fit_transform(wisata["Penjelasan"])

def rekomendasi_konten(deskripsi_input, top_n=5):
    input_tfidf = tfidf.transform([deskripsi_input])
    cosine_sim = cosine_similarity(input_tfidf, tfidf_matrix)
    top_indices = cosine_sim.argsort()[0][-top_n:][::-1]
    return wisata.iloc[top_indices][["NameLocation", "Provinsi", "Kategori", "Rating", "LinkGmaps"]]

# %%
with open("woofi_model.pkl", "wb") as f:
    pickle.dump((clf, tfidf, selector, imputer), f, protocol=4)
